# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pyalluvial.alluvial as alluvial

# %% [markdown]
# # Datos Alluvial

# %%
dicc = {'positive regulation of cellular metabolic process': 'Regulación positiva de procesos metabolicos', 
        'positive regulation of metabolic process': 'Regulación positiva de procesos metabolicos', 
        'positive regulation of cell population proliferation': 'Regulación positiva de proliferación celular',
       'cell population proliferation': 'Regulación positiva de proliferación celular',
        'protein phosphorylation': 'Fosforilación de proteinas',
        'regulation of cell population proliferation':'Regulación positiva de proliferación celular',
        'tube development':'Desarrollo de tubo',
        'tube morphogenesis': 'Morfogénesis de tubo',
        'Phosphate−containing compound metabolic process': 'Fosforilación de proteinas',
        'epithelial cell proliferation': 'Proliferación de células epiteliales', 
        'phosphorylation': 'Fosforilación',
        'positive regulation of protein metabolic process': 'Regulación positiva del metabolismo de proteínas',
        'Regulation of nitrogen compound metabolic process':'Regulación del proceso metabólico de compuestos de nitrógeno',
        'Negative regulation of cellular metabolic process':'Regulación negativa del proceso metabólico celular',
        'positive regulation of gene expression': 'Regulación positiva de la expresión genética',
        'cellular macromolecule biosynthetic process': 'Proceso biosintético de macromoléculas celulares',
        'regulation of epithelial cell proliferation': 'Regulación de la proliferación de células epiteliales',
        'regulation of protein serine/threonine kinase activity': 'Regulación de la proteína serina/treonina quinasa',
        'phosphate-containing compound metabolic process': 'Metabolismo de fosfato',
        'regulation of nitrogen compound metabolic process': 'Metabolismo de nitrógeno',
        'negative regulation of cellular metabolic process': 'Regulación negativa del metabolismo celular',
        'positive regulation of protein phosphorylation': 'Fosforilación de proteinas',
        'tissue development': 'Desarrollo de tejidos',
        'anatomical structure morphogenesis': 'Morfogénesis',
        'regulation of metabolic process':'Regulación del proceso metabólico',
        'muscle structure development': 'Desarrollo de estructura muscular',
        'cellular response to organic substance': 'Respuesta celular a sustancia orgánica',
        'regulation of cell differentiation': 'Regulación de diferenciación celular',
        'response to organonitrogen compound': 'Respuesta al compuesto organonitrogenado',
        'cell surface receptor signaling pathway': 'Señalización del receptor de superficie celular',
        'cell differentiation': 'Regulación de diferenciación celular', 
        'response to nitrogen compound': 'Respuesta al compuesto de nitrógeno'
       }

# %%
dft = pd.read_csv('../../Data/Estratos/Pathways_ExpressionFilter/Expanded_miRNAPredicted_time_Filter.tsv', sep = '\t')
dft.replace(dicc, inplace =  True)

dft_pathways_count = pd.DataFrame(dft[['function', 'Variant']].value_counts()).reset_index()
df_top10t = dft_pathways_count.groupby(['Variant']).head(15)

df_top10t.columns = ['Via', 'tiempo', 'conteo']


to_replace = {'(2021-01-01,2021-05-01]':1, '(2022-06-01,2022-11-01]':2,
       '(2022-01-01,2022-06-01]':3, '(2021-05-01,2022-01-01]':4,
       '(2023-01-01,2023-07-01]':5, '(2020-09-01,2021-01-01]':6,
       '(2023-07-01,2023-09-06]':7, '(2022-11-01,2023-01-01]':8,
       '(2010-12-05,2020-03-01]':9, '(2020-03-01,2020-09-01]':10}


df_top10t
# Out:
#                                                   Via  \
# 0        Regulación positiva de proliferación celular
# 1        Regulación positiva de proliferación celular
# 2        Regulación positiva de proliferación celular
# 3        Regulación positiva de proliferación celular
# 4        Regulación positiva de proliferación celular
# ..                                                ...
# 295                            mesenchyme development
# 297                            mesenchyme development
# 304                                   gene expression
# 319  regulation of transcription by RNA polymerase II
# 336                                system development
#
#                       tiempo  conteo
# 0    (2021-05-01,2022-01-01]      85
# 1    (2022-06-01,2022-11-01]      85
# 2    (2021-01-01,2021-05-01]      83
# 3    (2023-01-01,2023-07-01]      83
# 4    (2020-09-01,2021-01-01]      80
# ..                       ...     ...
# 295  (2010-12-05,2020-03-01]      18
# 297  (2020-03-01,2020-09-01]      18
# 304  (2010-12-05,2020-03-01]      18
# 319  (2020-03-01,2020-09-01]      18
# 336  (2020-03-01,2020-09-01]      18
#
# [150 rows x 3 columns]

# %%
df_top10t['RF'] = df_top10t['conteo'] / df_top10t.groupby('tiempo')['conteo'].transform('sum')
df_top10t.to_csv('/home/ferambriz/test.tsv', sep = '\t', index = False)
df_top10t
# Out:
# /tmp/ipykernel_6611/2680958968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                   Via  \
# 0        Regulación positiva de proliferación celular
# 1        Regulación positiva de proliferación celular
# 2        Regulación positiva de proliferación celular
# 3        Regulación positiva de proliferación celular
# 4        Regulación positiva de proliferación celular
# ..                                                ...
# 295                            mesenchyme development
# 297                            mesenchyme development
# 304                                   gene expression
# 319  regulation of transcription by RNA polymerase II
# 336                                system development
#
#                       tiempo  conteo        RF
# 0    (2021-05-01,2022-01-01]      85  0.165370
# 1    (2022-06-01,2022-11-01]      85  0.172764
# 2    (2021-01-01,2021-05-01]      83  0.160542
# 3    (2023-01-01,2023-07-01]      83  0.173640
# 4    (2020-09-01,2021-01-01]      80  0.163265
# ..                       ...     ...       ...
# 295  (2010-12-05,2020-03-01]      18  0.043689
# 297  (2020-03-01,2020-09-01]      18  0.044335
# 304  (2010-12-05,2020-03-01]      18  0.043689
# 319  (2020-03-01,2020-09-01]      18  0.044335
# 336  (2020-03-01,2020-09-01]      18  0.044335
#
# [150 rows x 4 columns]

# %% [markdown]
# # Otros

# %%
dfv = pd.read_csv('../../Data/Estratos/Pathways_ExpressionFilter/Expanded_miRNAPredicted_SinEstructuras_variant_Filter.tsv', sep = '\t')
dfs = pd.read_csv('../../Data/Estratos/Pathways_ExpressionFilter/Expanded_miRNAPredicted_spectral_Filter.tsv', sep = '\t')
dfsp = pd.read_csv('../../Data/Estratos/Pathways_ExpressionFilter/Expanded_miRNAPredicted_spectrum_Filter.tsv', sep = '\t')
dfgt = pd.read_csv('../../Data/Estratos/Pathways_ExpressionFilter/Expanded_miRNAPredicted_ConstantClusters_Filter.tsv', sep = '\t')
dfv
# Out:
#                                                  function   p_value  \
# 0       cellular response to parathyroid hormone stimulus  0.008178
# 1       negative regulation of DNA-binding transcripti...  0.008178
# 2                     negative regulation of ossification  0.013669
# 3       negative regulation of osteoblast differentiation  0.008178
# 4                              osteoblast differentiation  0.021794
# ...                                                   ...       ...
# 366168  vascular endothelial growth factor signaling p...  0.006034
# 366169                            vasculature development  0.004227
# 366170                                     vasculogenesis  0.019576
# 366171                                      wound healing  0.009199
# 366172                  wound healing, spreading of cells  0.028992
#
#                   miRNA Variant  DuplexEnergy   Jaccard Region  \
# 0        hsa-miR-381-3p     22F         -20.5  0.812500  3'UTR
# 1        hsa-miR-381-3p     22F         -20.5  0.812500  3'UTR
# 2        hsa-miR-381-3p     22F         -20.5  0.812500  3'UTR
# 3        hsa-miR-381-3p     22F         -20.5  0.812500  3'UTR
# 4        hsa-miR-381-3p     22F         -20.5  0.812500  3'UTR
# ...                 ...     ...           ...       ...    ...
# 366168  hsa-miR-199a-3p     21H         -10.0  0.916667  5'UTR
# 366169  hsa-miR-199a-3p     21H         -10.0  0.916667  5'UTR
# 366170  hsa-miR-199a-3p     21H         -10.0  0.916667  5'UTR
# 366171  hsa-miR-199a-3p     21H         -10.0  0.916667  5'UTR
# 366172  hsa-miR-199a-3p     21H         -10.0  0.916667  5'UTR
#
#               UTR_region InteractionRegionUTR  \
# 0       >22F:29760-29809                16,31
# 1       >22F:29760-29809                16,31
# 2       >22F:29760-29809                16,31
# 3       >22F:29760-29809                16,31
# 4       >22F:29760-29809                16,31
# ...                  ...                  ...
# 366168      >21H:256-255                 1,12
# 366169      >21H:256-255                 1,12
# 366170      >21H:256-255                 1,12
# 366171      >21H:256-255                 1,12
# 366172      >21H:256-255                 1,12
#
#                                                Expression  ...         lung  \
# 0       {'kidney': 47.3691337301885, 'brain': 282.3801...  ...    12.382684
# 1       {'kidney': 47.3691337301885, 'brain': 282.3801...  ...    12.382684
# 2       {'kidney': 47.3691337301885, 'brain': 282.3801...  ...    12.382684
# 3       {'kidney': 47.3691337301885, 'brain': 282.3801...  ...    12.382684
# 4       {'kidney': 47.3691337301885, 'brain': 282.3801...  ...    12.382684
# ...                                                   ...  ...          ...
# 366168  {'kidney': 13264.606798709408, 'brain': 191.82...  ...  5440.077182
# 366169  {'kidney': 13264.606798709408, 'brain': 191.82...  ...  5440.077182
# 366170  {'kidney': 13264.606798709408, 'brain': 191.82...  ...  5440.077182
# 366171  {'kidney': 13264.606798709408, 'brain': 191.82...  ...  5440.077182
# 366172  {'kidney': 13264.606798709408, 'brain': 191.82...  ...  5440.077182
#
#            esophagus        kidney        artery         heart         vein  \
# 0          26.206047     47.369134      6.166493     28.999434    17.336111
# 1          26.206047     47.369134      6.166493     28.999434    17.336111
# 2          26.206047     47.369134      6.166493     28.999434    17.336111
# 3          26.206047     47.369134      6.166493     28.999434    17.336111
# 4          26.206047     47.369134      6.166493     28.999434    17.336111
# ...              ...           ...           ...           ...          ...
# 366168  11569.106880  13264.606799  13520.519870  16381.427129  7599.012124
# 366169  11569.106880  13264.606799  13520.519870  16381.427129  7599.012124
# 366170  11569.106880  13264.606799  13520.519870  16381.427129  7599.012124
# 366171  11569.106880  13264.606799  13520.519870  16381.427129  7599.012124
# 366172  11569.106880  13264.606799  13520.519870  16381.427129  7599.012124
#
#            pancreas       stomach        liver   0
# 0         26.912480    128.365923     36.05762 NaN
# 1         26.912480    128.365923     36.05762 NaN
# 2         26.912480    128.365923     36.05762 NaN
# 3         26.912480    128.365923     36.05762 NaN
# 4         26.912480    128.365923     36.05762 NaN
# ...             ...           ...          ...  ..
# 366168  7527.710558  15835.569036  13632.12653 NaN
# 366169  7527.710558  15835.569036  13632.12653 NaN
# 366170  7527.710558  15835.569036  13632.12653 NaN
# 366171  7527.710558  15835.569036  13632.12653 NaN
# 366172  7527.710558  15835.569036  13632.12653 NaN
#
# [366173 rows x 23 columns]

# %%
dft['function'] = dft['function'].replace(dicc)
dfv['function'] = dfv['function'].replace(dicc)
dfs['function'] = dfs['function'].replace(dicc)
dfsp['function'] = dfsp['function'].replace(dicc)
dfgt['function'] = dfgt['function'].replace(dicc)

# %% [markdown]
# # Inspeccion por variante

# %%
dfv_pathways_count = pd.DataFrame(dfv[['function', 'Variant', 'Region']].value_counts()).reset_index()
dfv_pathways_count
# Out:
#                                              function      Variant Region   0
# 0        Regulación positiva de proliferación celular          21I  5'UTR  88
# 1        Regulación positiva de proliferación celular          20D  5'UTR  81
# 2        Regulación positiva de proliferación celular          21H  5'UTR  71
# 3         Regulación positiva de procesos metabolicos          21I  5'UTR  70
# 4        Regulación positiva de proliferación celular          23C  5'UTR  70
# ...                                               ...          ...    ...  ..
# 144914  negative regulation of mRNA catabolic process          21I  3'UTR   1
# 144915  negative regulation of mRNA catabolic process          21H  5'UTR   1
# 144916  negative regulation of mRNA catabolic process          21H  3'UTR   1
# 144917  negative regulation of mRNA catabolic process          21G  5'UTR   1
# 144918                 neuron projection regeneration  recombinant  5'UTR   1
#
# [144919 rows x 4 columns]

# %%
df_top10v = dfv_pathways_count.groupby(['Variant', 'Region']).head(15)

df_top10v_5 = df_top10v[df_top10v['Region']=="5'UTR"].drop(['Region'], axis = 1)
df_top10v_3 = df_top10v[df_top10v['Region']=="3'UTR"].drop(['Region'], axis = 1)

mat_v5 = df_top10v_5.pivot(index='function', columns=['Variant'], values=0)
mat_v3 = df_top10v_3.pivot(index='function', columns=['Variant'], values=0)
mat_v5
# Out:
# Variant                                            19A   19B   20A   20B  \
# function
# Desarrollo de tubo                                 NaN   NaN   NaN   NaN
# Fosforilación                                      9.0   NaN  10.0  25.0
# Fosforilación de proteinas                        17.0  17.0  18.0  44.0
# Metabolismo de fosfato                             NaN   NaN   NaN   NaN
# Metabolismo de nitrógeno                           9.0   NaN   NaN  23.0
# ...                                                ...   ...   ...   ...
# regulation of transcription by RNA polymerase II   NaN   NaN   9.0   NaN
# response to growth factor                          NaN   NaN   NaN   NaN
# system development                                 NaN   NaN   NaN  21.0
# transcription by RNA polymerase II                 NaN   NaN  11.0  21.0
# vasculature development                            NaN   NaN   NaN   NaN
#
# Variant                                            20C   20D   20E   20F  \
# function
# Desarrollo de tubo                                 9.0  24.0   NaN   NaN
# Fosforilación                                      NaN  28.0  15.0  11.0
# Fosforilación de proteinas                        16.0  49.0  28.0  20.0
# Metabolismo de fosfato                             NaN   NaN   NaN   NaN
# Metabolismo de nitrógeno                           NaN  31.0  17.0  11.0
# ...                                                ...   ...   ...   ...
# regulation of transcription by RNA polymerase II   NaN   NaN  15.0   NaN
# response to growth factor                          9.0   NaN   NaN   NaN
# system development                                 NaN  24.0   NaN   NaN
# transcription by RNA polymerase II                 NaN  28.0  18.0  11.0
# vasculature development                            NaN   NaN   NaN   NaN
#
# Variant                                            20G   20H  ...   22D   22E  \
# function                                                      ...
# Desarrollo de tubo                                 NaN   NaN  ...   NaN  20.0
# Fosforilación                                     11.0  15.0  ...  16.0  22.0
# Fosforilación de proteinas                        21.0  26.0  ...  29.0  38.0
# Metabolismo de fosfato                             NaN   NaN  ...   NaN   NaN
# Metabolismo de nitrógeno                           NaN  17.0  ...  21.0  24.0
# ...                                                ...   ...  ...   ...   ...
# regulation of transcription by RNA polymerase II  10.0  16.0  ...  15.0   NaN
# response to growth factor                          NaN   NaN  ...   NaN   NaN
# system development                                 NaN   NaN  ...   NaN  19.0
# transcription by RNA polymerase II                11.0  19.0  ...  19.0  21.0
# vasculature development                            NaN   NaN  ...   NaN   NaN
#
# Variant                                            22F   23A   23B   23C  \
# function
# Desarrollo de tubo                                20.0   NaN   NaN   NaN
# Fosforilación                                     21.0  15.0  14.0  25.0
# Fosforilación de proteinas                        35.0  25.0  27.0  44.0
# Metabolismo de fosfato                             NaN   NaN   NaN   NaN
# Metabolismo de nitrógeno                          22.0  16.0  14.0  27.0
# ...                                                ...   ...   ...   ...
# regulation of transcription by RNA polymerase II   NaN  15.0  13.0   NaN
# response to growth factor                          NaN   NaN   NaN   NaN
# system development                                18.0   NaN   NaN   NaN
# transcription by RNA polymerase II                20.0  17.0  15.0  23.0
# vasculature development                           18.0   NaN   NaN   NaN
#
# Variant                                            23D   23E   23F  \
# function
# Desarrollo de tubo                                 NaN  13.0   NaN
# Fosforilación                                      NaN   NaN  15.0
# Fosforilación de proteinas                        15.0  21.0  26.0
# Metabolismo de fosfato                             NaN   NaN  12.0
# Metabolismo de nitrógeno                           NaN  13.0  13.0
# ...                                                ...   ...   ...
# regulation of transcription by RNA polymerase II   NaN   NaN   NaN
# response to growth factor                          NaN   NaN   NaN
# system development                                 NaN   NaN   NaN
# transcription by RNA polymerase II                 NaN  13.0  15.0
# vasculature development                            NaN   NaN   NaN
#
# Variant                                           recombinant
# function
# Desarrollo de tubo                                       10.0
# Fosforilación                                            10.0
# Fosforilación de proteinas                               19.0
# Metabolismo de fosfato                                    NaN
# Metabolismo de nitrógeno                                  NaN
# ...                                                       ...
# regulation of transcription by RNA polymerase II          NaN
# response to growth factor                                 NaN
# system development                                        NaN
# transcription by RNA polymerase II                        NaN
# vasculature development                                  11.0
#
# [62 rows x 38 columns]

# %%
mat_v5.to_csv('../../Data/Estratos/Pathways_ExpressionFilter/MatrixPathwaysTop15_variants_region5.tsv', sep = '\t')
mat_v3.to_csv('../../Data/Estratos/Pathways_ExpressionFilter/MatrixPathwaysTop15_variants_region3.tsv', sep = '\t')

# %% [markdown]
# # Generate data to EULER PLOT

# %%
g1 = list(dfsp[dfsp['Variant']=='Gs1']['miRNA'])
g2 = list(dfsp[dfsp['Variant']=='Gs2']['miRNA'])
g3 = list(dfsp[dfsp['Variant']=='Gs3']['miRNA'])
g4 = list(dfsp[dfsp['Variant']=='Gs4']['miRNA'])

eval = 0; contador = 0
for i in [g1, g2, g3, g4]:
    if len(i) > eval:
        print(f'{contador}', {len(i)})
        eval = len(i)
    contador +=1

g1 = g1 + ['NaN']*(eval - len(g1))
g2 = g2 + ['NaN']*(eval - len(g2))
g4 = g4 + ['NaN']*(eval - len(g4))

len(g2)
# Out:
# 0 {11986}
# 2 {12134}
# 12134

# %%
df = pd.DataFrame({
                   'miRNA_Estrato_0': g1,
                   'miRNA_Estrato_1': g2, 
                   'miRNA_Estrato_2': g3, 
                   'miRNA_Estrato_3': g4
                  })
df
# Out:
#        miRNA_Estrato_0  miRNA_Estrato_1  miRNA_Estrato_2  miRNA_Estrato_3
# 0      hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p
# 1      hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p
# 2      hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p
# 3      hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p
# 4      hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p  hsa-miR-193a-5p
# ...                ...              ...              ...              ...
# 12129              NaN              NaN   hsa-miR-29b-3p              NaN
# 12130              NaN              NaN   hsa-miR-29b-3p              NaN
# 12131              NaN              NaN   hsa-miR-29b-3p              NaN
# 12132              NaN              NaN   hsa-miR-29b-3p              NaN
# 12133              NaN              NaN   hsa-miR-29b-3p              NaN
#
# [12134 rows x 4 columns]

# %%
df.to_csv('../../Data/Estratos/miRNA_predichos_SpectrumEuler.tsv', sep = '\t', index = False)
