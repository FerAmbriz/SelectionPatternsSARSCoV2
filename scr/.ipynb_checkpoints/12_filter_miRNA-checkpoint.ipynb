# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from multiprocessing import Pool
import seaborn as sns
import matplotlib.animation as animation
import matplotlib.gridspec as gridspec
from scipy import stats
from statsmodels.formula.api import ols
import statsmodels.api as sm
import scikit_posthocs as sp

# %% [markdown]
# # Extraccion de datos

# %%
def extract_num(string):
    if isinstance(string, str):
        return float(string.split('(')[1].split(')')[0])
    elif isinstance(string, float):
        return string
    else:
        return None

#calcula el indice de jaccard en al region semilla
def calculate_jaccard (Interaction):
    lst = Interaction.split('&')
    puntos = 0
    seedpair = 0
    #parentesis_cerrados = 0
    
    for cadena in lst[0]:
        puntos += cadena.count('.')
        seedpair += cadena.count('(')
        #parentesis_cerrados += cadena.count(')')
        
    j = (seedpair) / (puntos + seedpair)
    return j



def clean_df(df):
    
    lst_conserved =[]; lst_miRNA = []; lst_prediction = []
    for i in range(len(df[0])-2):
        header = df[0][i]; miRNA = df[0][i+1]; prediction = df[0][i+2]
        
        if prediction.startswith('.') or prediction.startswith('('):
            bool_prediction = True
        else:
            bool_prediction = False
            
        if header.startswith('>') and miRNA.startswith('>hsa') and bool_prediction == True:
            lst_conserved.append(header); lst_miRNA.append(miRNA); lst_prediction.append(prediction)

    df = pd.DataFrame({
        'UTR_region': lst_conserved,
        'miRNA':lst_miRNA, 
        'Prediction':lst_prediction})

    df['Prediction'] = df['Prediction'].str.replace('( ', '(', regex=False)
    df['Prediction'] = df['Prediction'].str.replace('< ', '<', regex=False)
    df_e = df['Prediction'].apply(lambda x: x.split()).apply(pd.Series)
    df = pd.concat([df, df_e], axis = 1)
    
    df.drop([2], axis=1, inplace = True)
    df.columns = ['UTR_region', 'miRNA', 'Prediction', 'Interaction', 'InteractionRegionUTR', 
              'InteractionRegionmiRNA', 'DuplexEnergy', 'InteractionResidues', 'MinimumEnergy']
    
    df['DuplexEnergy'] = list(map(extract_num, df['DuplexEnergy']))
    df = df.sort_values(by=['DuplexEnergy'])

    df['Jaccard'] = list(map(calculate_jaccard, df['Interaction']))
    
    UTR3 = 29674
    UTR5 = 265

    lst_type = []
    for i in df['UTR_region']: 
        start,end = i.split(':')[1].split('-')
        if int(end) <= UTR5:
            lst_type.append("5'UTR")
        else:
            lst_type.append("3'UTR")
    df['Region'] = lst_type

    lst = []
    for i in df['UTR_region']:
        lst.append(i.split(':')[0].split('>')[1])
    df['Variant'] = lst
    return df

# %%
dfv = pd.read_csv('../../Data/Estratos/miRNA_predict/conserved_SinFold_regions_UTR_variants_predicted_miRNA.txt', sep = '\t', header = None)
dfv = clean_df(dfv)
dfv
# Out:
#                UTR_region             miRNA  \
# 59085         >20A:29-173      >hsa-miR-638
# 292706        >20G:34-202      >hsa-miR-638
# 5995          >19A:29-218      >hsa-miR-638
# 709470        >21G:67-185      >hsa-miR-638
# 828944        >21J:26-173      >hsa-miR-638
# ...                   ...               ...
# 1447772  >recombinant:1-4  >hsa-miR-1249-3p
# 1413455      >23F:200-203  >hsa-miR-3162-3p
# 330311         >20H:17-20  >hsa-miR-3162-3p
# 1119           >19A:17-20  >hsa-miR-3162-3p
# 444443         >21A:16-20  >hsa-miR-3162-3p
#
#                                                 Prediction  \
# 59085    .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 292706   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 5995     .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 709470   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 828944   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# ...                                                    ...
# 1447772    .(.&.)   2,4   :  21,22  (4.10) i:3,j:22 <3.60>
# 1413455    .(.&.)   1,3   :  20,21  (4.30) i:3,j:21 <3.80>
# 330311     .(.&.)   1,3   :  20,21  (4.30) i:2,j:21 <3.80>
# 1119       .(.&.)   1,3   :  20,21  (4.30) i:2,j:21 <3.80>
# 444443     .(.&.)   2,4   :  20,21  (4.30) i:3,j:21 <3.80>
#
#                                                Interaction  \
# 59085    .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 292706   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 5995     .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 709470   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 828944   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# ...                                                    ...
# 1447772                                             .(.&.)
# 1413455                                             .(.&.)
# 330311                                              .(.&.)
# 1119                                                .(.&.)
# 444443                                              .(.&.)
#
#         InteractionRegionUTR InteractionRegionmiRNA  DuplexEnergy  \
# 59085                  61,85                   1,25         -34.5
# 292706                 56,80                   1,25         -34.5
# 5995                   61,85                   1,25         -34.5
# 709470                 23,47                   1,25         -34.5
# 828944                 64,88                   1,25         -34.5
# ...                      ...                    ...           ...
# 1447772                  2,4                  21,22           4.1
# 1413455                  1,3                  20,21           4.3
# 330311                   1,3                  20,21           4.3
# 1119                     1,3                  20,21           4.3
# 444443                   2,4                  20,21           4.3
#
#         InteractionResidues MinimumEnergy   Jaccard Region      Variant
# 59085              i:84,j:1      <-34.60>  0.840000  5'UTR          20A
# 292706             i:79,j:1      <-34.60>  0.840000  5'UTR          20G
# 5995               i:84,j:1      <-34.60>  0.840000  5'UTR          19A
# 709470             i:46,j:1      <-34.60>  0.840000  5'UTR          21G
# 828944             i:87,j:1      <-34.60>  0.840000  5'UTR          21J
# ...                     ...           ...       ...    ...          ...
# 1447772            i:3,j:22        <3.60>  0.333333  5'UTR  recombinant
# 1413455            i:3,j:21        <3.80>  0.333333  5'UTR          23F
# 330311             i:2,j:21        <3.80>  0.333333  5'UTR          20H
# 1119               i:2,j:21        <3.80>  0.333333  5'UTR          19A
# 444443             i:3,j:21        <3.80>  0.333333  5'UTR          21A
#
# [1502610 rows x 12 columns]

# %%
dft = pd.read_csv('../../Data/Estratos/miRNA_predict/conserved_regions_UTR_time_predicted_miRNA.txt', sep = '\t', header = None)
dft = clean_df(dft)
dft
# Out:
#                                   UTR_region             miRNA  \
# 329976       >(2022-11-01,2023-01-01]:45-209      >hsa-miR-638
# 186600       >(2021-05-01,2022-01-01]:26-173      >hsa-miR-638
# 290152       >(2022-06-01,2022-11-01]:45-202      >hsa-miR-638
# 422889       >(2023-07-01,2023-09-06]:45-202      >hsa-miR-638
# 377753       >(2023-01-01,2023-07-01]:45-192      >hsa-miR-638
# ...                                      ...               ...
# 363952  >(2022-11-01,2023-01-01]:29890-29903   >hsa-miR-214-3p
# 365617  >(2022-11-01,2023-01-01]:29890-29903  >hsa-miR-4768-3p
# 411744  >(2023-01-01,2023-07-01]:29871-29903   >hsa-miR-214-3p
# 63539         >(2020-09-01,2021-01-01]:16-15  >hsa-miR-6891-3p
# 154968  >(2021-01-01,2021-05-01]:29728-29727  >hsa-miR-1249-3p
#
#                                                Prediction  \
# 329976  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 186600  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 290152  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 422889  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 377753  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# ...                                                   ...
# 363952   .(.&.)   1,3   :  21,22  (4.00) i:13,j:22 <3.60>
# 365617   .(.&.)   1,3   :  19,20  (4.00) i:13,j:20 <3.60>
# 411744   .(.&.)   1,3   :  21,22  (4.00) i:32,j:22 <3.60>
# 63539      .(&.).   3,4   :   5,7   (4.00) i:4,j:6 <3.70>
# 154968    .(.&.)   1,3   :  21,22  (4.20) i:5,j:22 <3.80>
#
#                                               Interaction  \
# 329976  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 186600  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 290152  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 422889  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 377753  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# ...                                                   ...
# 363952                                             .(.&.)
# 365617                                             .(.&.)
# 411744                                             .(.&.)
# 63539                                              .(&.).
# 154968                                             .(.&.)
#
#        InteractionRegionUTR InteractionRegionmiRNA  DuplexEnergy  \
# 329976                45,69                   1,25         -34.5
# 186600                64,88                   1,25         -34.5
# 290152                45,69                   1,25         -34.5
# 422889                45,69                   1,25         -34.5
# 377753                45,69                   1,25         -34.5
# ...                     ...                    ...           ...
# 363952                  1,3                  21,22           4.0
# 365617                  1,3                  19,20           4.0
# 411744                  1,3                  21,22           4.0
# 63539                   3,4                    5,7           4.0
# 154968                  1,3                  21,22           4.2
#
#        InteractionResidues MinimumEnergy   Jaccard Region  \
# 329976            i:68,j:1      <-34.60>  0.840000  5'UTR
# 186600            i:87,j:1      <-34.60>  0.840000  5'UTR
# 290152            i:68,j:1      <-34.60>  0.840000  5'UTR
# 422889            i:68,j:1      <-34.60>  0.840000  5'UTR
# 377753            i:68,j:1      <-34.60>  0.840000  5'UTR
# ...                    ...           ...       ...    ...
# 363952           i:13,j:22        <3.60>  0.333333  3'UTR
# 365617           i:13,j:20        <3.60>  0.333333  3'UTR
# 411744           i:32,j:22        <3.60>  0.333333  3'UTR
# 63539              i:4,j:6        <3.70>  0.500000  5'UTR
# 154968            i:5,j:22        <3.80>  0.333333  3'UTR
#
#                         Variant
# 329976  (2022-11-01,2023-01-01]
# 186600  (2021-05-01,2022-01-01]
# 290152  (2022-06-01,2022-11-01]
# 422889  (2023-07-01,2023-09-06]
# 377753  (2023-01-01,2023-07-01]
# ...                         ...
# 363952  (2022-11-01,2023-01-01]
# 365617  (2022-11-01,2023-01-01]
# 411744  (2023-01-01,2023-07-01]
# 63539   (2020-09-01,2021-01-01]
# 154968  (2021-01-01,2021-05-01]
#
# [464686 rows x 12 columns]

# %%
dfgt = pd.read_csv('../../Data/Estratos/miRNA_predict/conserved_regions_UTR_ConstantClusters_predicted_miRNA.txt', sep = '\t', header = None)
dfgt = clean_df(dfgt)
dfgt
# Out:
#                UTR_region             miRNA  \
# 11307        >Gst1:67-209      >hsa-miR-638
# 12816        >Gst1:67-209  >hsa-miR-6762-5p
# 12429        >Gst1:67-209  >hsa-miR-4758-5p
# 11485        >Gst1:67-209  >hsa-miR-1226-5p
# 12482        >Gst1:67-209  >hsa-miR-4787-5p
# ...                   ...               ...
# 39192   >Gst1:29871-29903     >hsa-miR-5703
# 98388   >Gst2:29890-29903   >hsa-miR-214-3p
# 38996   >Gst1:29871-29903  >hsa-miR-4768-3p
# 100457  >Gst2:29890-29903  >hsa-miR-6781-5p
# 97608   >Gst2:29888-29887     >hsa-miR-5703
#
#                                                Prediction  \
# 11307   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 12816   .(((((((((((..(((((((.&)))))))...))))))))))). ...
# 12429   .((((.((((.(((((.(..........(((((((.&))))))))....
# 11485   .(((((.(..(.(((((((((.......(((((.&)))))))))))...
# 12482   .((((.((((((((((..((((.&)))))))))))))).)))).  ...
# ...                                                   ...
# 39192    .(.&.)   1,3   :  17,18  (4.00) i:32,j:18 <3.60>
# 98388    .(.&.)   1,3   :  21,22  (4.00) i:13,j:22 <3.60>
# 38996    .(.&.)   1,3   :  19,20  (4.00) i:32,j:20 <3.60>
# 100457   .(.&.)   1,3   :  20,21  (4.00) i:13,j:21 <3.60>
# 97608    .(.&.)   1,3   :  17,18  (4.00) i:17,j:18 <3.60>
#
#                                               Interaction  \
# 11307   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 12816       .(((((((((((..(((((((.&)))))))...))))))))))).
# 12429   .((((.((((.(((((.(..........(((((((.&))))))))....
# 11485   .(((((.(..(.(((((((((.......(((((.&)))))))))))...
# 12482        .((((.((((((((((..((((.&)))))))))))))).)))).
# ...                                                   ...
# 39192                                              .(.&.)
# 98388                                              .(.&.)
# 38996                                              .(.&.)
# 100457                                             .(.&.)
# 97608                                              .(.&.)
#
#        InteractionRegionUTR InteractionRegionmiRNA  DuplexEnergy  \
# 11307                 23,47                   1,25         -34.5
# 12816               118,139                   1,22         -29.1
# 12429                 23,58                   1,23         -28.3
# 11485                 25,58                   1,25         -27.9
# 12482                 19,41                   1,20         -27.9
# ...                     ...                    ...           ...
# 39192                   1,3                  17,18           4.0
# 98388                   1,3                  21,22           4.0
# 38996                   1,3                  19,20           4.0
# 100457                  1,3                  20,21           4.0
# 97608                   1,3                  17,18           4.0
#
#        InteractionResidues MinimumEnergy   Jaccard Region Variant
# 11307             i:46,j:1      <-34.60>  0.840000  5'UTR    Gst1
# 12816            i:138,j:1      <-29.20>  0.818182  5'UTR    Gst1
# 12429             i:57,j:1      <-26.90>  0.583333  5'UTR    Gst1
# 11485             i:57,j:1      <-27.40>  0.617647  5'UTR    Gst1
# 12482             i:40,j:1      <-27.60>  0.782609  5'UTR    Gst1
# ...                    ...           ...       ...    ...     ...
# 39192            i:32,j:18        <3.60>  0.333333  3'UTR    Gst1
# 98388            i:13,j:22        <3.60>  0.333333  3'UTR    Gst2
# 38996            i:32,j:20        <3.60>  0.333333  3'UTR    Gst1
# 100457           i:13,j:21        <3.60>  0.333333  3'UTR    Gst2
# 97608            i:17,j:18        <3.60>  0.333333  3'UTR    Gst2
#
# [100882 rows x 12 columns]

# %%
dfs = pd.read_csv('../../Data/Estratos/miRNA_predict/conserved_regions_UTR_spectral_predicted_miRNA.txt', sep = '\t', header = None)
dfs = clean_df(dfs)
dfs
# Out:
#              UTR_region             miRNA  \
# 72350        >G2:67-125      >hsa-miR-638
# 73472        >G2:67-125  >hsa-miR-4758-5p
# 73525        >G2:67-125  >hsa-miR-4787-5p
# 72528        >G2:67-125  >hsa-miR-1226-5p
# 72343        >G2:67-125   >hsa-miR-33b-3p
# ...                 ...               ...
# 60633   >G1:29891-29894  >hsa-miR-6781-5p
# 55923   >G1:29883-29886   >hsa-miR-214-3p
# 60229   >G1:29891-29894  >hsa-miR-4768-3p
# 108007  >G2:29873-29903  >hsa-miR-4768-3p
# 276307  >G5:29871-29881   >hsa-miR-214-3p
#
#                                                Prediction  \
# 72350   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 73472   .((((.((((.(((((.(..........(((((((.&))))))))....
# 73525   .((((.((((((((((..((((.&)))))))))))))).)))).  ...
# 72528   .(((((.(..(.(((((((((.......(((((.&)))))))))))...
# 72343   .(((((((((((.((.(((((.&.))))))).)))).))))))). ...
# ...                                                   ...
# 60633     .(.&.)   1,3   :  20,21  (4.00) i:3,j:21 <3.60>
# 55923     .(.&.)   1,3   :  21,22  (4.00) i:3,j:22 <3.60>
# 60229     .(.&.)   1,3   :  19,20  (4.00) i:3,j:20 <3.60>
# 108007   .(.&.)   1,3   :  19,20  (4.00) i:30,j:20 <3.60>
# 276307   .(.&.)   1,3   :  21,22  (4.00) i:10,j:22 <3.60>
#
#                                               Interaction  \
# 72350   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 73472   .((((.((((.(((((.(..........(((((((.&))))))))....
# 73525        .((((.((((((((((..((((.&)))))))))))))).)))).
# 72528   .(((((.(..(.(((((((((.......(((((.&)))))))))))...
# 72343       .(((((((((((.((.(((((.&.))))))).)))).))))))).
# ...                                                   ...
# 60633                                              .(.&.)
# 55923                                              .(.&.)
# 60229                                              .(.&.)
# 108007                                             .(.&.)
# 276307                                             .(.&.)
#
#        InteractionRegionUTR InteractionRegionmiRNA  DuplexEnergy  \
# 72350                 23,47                   1,25         -34.5
# 73472                 23,58                   1,23         -28.3
# 73525                 19,41                   1,20         -27.9
# 72528                 25,58                   1,25         -27.9
# 72343                 34,55                   1,22         -27.9
# ...                     ...                    ...           ...
# 60633                   1,3                  20,21           4.0
# 55923                   1,3                  21,22           4.0
# 60229                   1,3                  19,20           4.0
# 108007                  1,3                  19,20           4.0
# 276307                  1,3                  21,22           4.0
#
#        InteractionResidues MinimumEnergy   Jaccard Region Variant
# 72350             i:46,j:1      <-34.60>  0.840000  5'UTR      G2
# 73472             i:57,j:1      <-26.90>  0.583333  5'UTR      G2
# 73525             i:40,j:1      <-27.60>  0.782609  5'UTR      G2
# 72528             i:57,j:1      <-27.40>  0.617647  5'UTR      G2
# 72343             i:54,j:2      <-27.90>  0.818182  5'UTR      G2
# ...                    ...           ...       ...    ...     ...
# 60633             i:3,j:21        <3.60>  0.333333  3'UTR      G1
# 55923             i:3,j:22        <3.60>  0.333333  3'UTR      G1
# 60229             i:3,j:20        <3.60>  0.333333  3'UTR      G1
# 108007           i:30,j:20        <3.60>  0.333333  3'UTR      G2
# 276307           i:10,j:22        <3.60>  0.333333  3'UTR      G5
#
# [281442 rows x 12 columns]

# %%
dfsp = pd.read_csv('../../Data/Estratos/miRNA_predict/conserved_regions_UTR_spectrum_predicted_miRNA.txt', sep = '\t', header = None)
dfsp = clean_df(dfsp)
dfsp
# Out:
#               UTR_region             miRNA  \
# 53787        >Gs2:45-173      >hsa-miR-638
# 157352       >Gs4:45-209      >hsa-miR-638
# 5995         >Gs1:45-173      >hsa-miR-638
# 93625        >Gs3:45-173      >hsa-miR-638
# 158861       >Gs4:45-209  >hsa-miR-6762-5p
# ...                  ...               ...
# 196068  >Gs4:29873-29903  >hsa-miR-6781-5p
# 45298   >Gs1:29882-29903   >hsa-miR-214-3p
# 195664  >Gs4:29873-29903  >hsa-miR-4768-3p
# 145216  >Gs3:29871-29903  >hsa-miR-4768-3p
# 46963   >Gs1:29882-29903  >hsa-miR-4768-3p
#
#                                                Prediction  \
# 53787   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 157352  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 5995    .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 93625   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 158861  .(((((((((((..(((((((.&)))))))...))))))))))). ...
# ...                                                   ...
# 196068   .(.&.)   1,3   :  20,21  (4.00) i:30,j:21 <3.60>
# 45298    .(.&.)   1,3   :  21,22  (4.00) i:21,j:22 <3.60>
# 195664   .(.&.)   1,3   :  19,20  (4.00) i:30,j:20 <3.60>
# 145216   .(.&.)   1,3   :  19,20  (4.00) i:32,j:20 <3.60>
# 46963    .(.&.)   1,3   :  19,20  (4.00) i:21,j:20 <3.60>
#
#                                               Interaction  \
# 53787   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 157352  .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 5995    .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 93625   .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 158861      .(((((((((((..(((((((.&)))))))...))))))))))).
# ...                                                   ...
# 196068                                             .(.&.)
# 45298                                              .(.&.)
# 195664                                             .(.&.)
# 145216                                             .(.&.)
# 46963                                              .(.&.)
#
#        InteractionRegionUTR InteractionRegionmiRNA  DuplexEnergy  \
# 53787                 45,69                   1,25         -34.5
# 157352                45,69                   1,25         -34.5
# 5995                  45,69                   1,25         -34.5
# 93625                 45,69                   1,25         -34.5
# 158861              140,161                   1,22         -29.1
# ...                     ...                    ...           ...
# 196068                  1,3                  20,21           4.0
# 45298                   1,3                  21,22           4.0
# 195664                  1,3                  19,20           4.0
# 145216                  1,3                  19,20           4.0
# 46963                   1,3                  19,20           4.0
#
#        InteractionResidues MinimumEnergy   Jaccard Region Variant
# 53787             i:68,j:1      <-34.60>  0.840000  5'UTR     Gs2
# 157352            i:68,j:1      <-34.60>  0.840000  5'UTR     Gs4
# 5995              i:68,j:1      <-34.60>  0.840000  5'UTR     Gs1
# 93625             i:68,j:1      <-34.60>  0.840000  5'UTR     Gs3
# 158861           i:160,j:1      <-29.20>  0.818182  5'UTR     Gs4
# ...                    ...           ...       ...    ...     ...
# 196068           i:30,j:21        <3.60>  0.333333  3'UTR     Gs4
# 45298            i:21,j:22        <3.60>  0.333333  3'UTR     Gs1
# 195664           i:30,j:20        <3.60>  0.333333  3'UTR     Gs4
# 145216           i:32,j:20        <3.60>  0.333333  3'UTR     Gs3
# 46963            i:21,j:20        <3.60>  0.333333  3'UTR     Gs1
#
# [196493 rows x 12 columns]

# %%
dft.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Time_SinFiltrar.tsv', sep = '\t', index = False)
dfv.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conservedSinEstructuraSecundaria_Variants_SinFiltrar.tsv', sep = '\t', index = False)

dfgt.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_ConstantClusters_SinFiltrar.tsv', sep = '\t', index = False)
dfs.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Spectral_SinFiltrar.tsv', sep = '\t', index = False)
dfsp.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Spectrum_SinFiltrar.tsv', sep = '\t', index = False)

# %% [markdown]
# # Inspeccion

# %%
dft = pd.read_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Time_SinFiltrar.tsv', sep = '\t')
dfv = pd.read_csv('../../Data/Estratos/miRNA_predict/miRNA_conservedSinEstructuraSecundaria_Variants_SinFiltrar.tsv', sep = '\t')
dfgt = pd.read_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_ConstantClusters_SinFiltrar.tsv', sep = '\t')
dfs = pd.read_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Spectral_SinFiltrar.tsv', sep = '\t')
dfsp = pd.read_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Spectrum_SinFiltrar.tsv', sep = '\t')

# %%
df_list = [dft, dfv, dfgt, dfs, dfsp]
df_db = pd.DataFrame()
df_db2 = pd.DataFrame()


for i in df_list:
    ii = i[i['Variant']!='Global']
    df_name = [name for name in globals() if globals()[name] is i]
    

    df_i = pd.DataFrame(ii['Variant'].value_counts())
    df_i['Table'] = df_name[0]
    df_i['Filter'] = 'Global'

    df_i2 = pd.DataFrame(ii[['Variant', 'Region']].groupby('Variant').value_counts().reset_index())
    df_i2['Table'] = df_name[0]


    print(f'''
        Nombre: {df_name}
        miRNA predichos: {len(ii)}
        Promedio por variante: {ii['Variant'].value_counts().agg(['mean', 'std'], numeric_only=True)}
        Region:
            mean
            {ii[['Variant', 'Region']].groupby('Variant').value_counts().reset_index().groupby('Region').mean(numeric_only=True)},
            std
            {ii[['Variant', 'Region']].groupby('Variant').value_counts().reset_index().groupby('Region').std(numeric_only=True)}

    ========
    ''')
    df_db = pd.concat([df_db, df_i])
    df_db2 = pd.concat([df_db2, df_i2])
# Out:
#         Nombre: ['dft', 'i']
#         miRNA predichos: 464686
#         Promedio por variante: mean    46468.600000
# std     12218.514414
# Name: count, dtype: float64
#         Region:
#             mean
#                       count
# Region
# 3'UTR   28939.0
# 5'UTR   17529.6,
#             std
#                           count
# Region
# 3'UTR   7660.626113
# 5'UTR   5341.429588
#
#     ========
#
#
#         Nombre: ['dfv', 'i']
#         miRNA predichos: 1502610
#         Promedio por variante: mean    39542.368421
# std      8300.801018
# Name: count, dtype: float64
#         Region:
#             mean
#                            count
# Region
# 3'UTR   18783.631579
# 5'UTR   20758.736842,
#             std
#                           count
# Region
# 3'UTR   5066.748904
# 5'UTR   4934.470489
#
#     ========
#
#
#         Nombre: ['dfgt', 'i']
#         miRNA predichos: 100882
#         Promedio por variante: mean    50441.000000
# std     15013.291178
# Name: count, dtype: float64
#         Region:
#             mean
#                       count
# Region
# 3'UTR   29193.0
# 5'UTR   21248.0,
#             std
#                            count
# Region
# 3'UTR   11257.139956
# 5'UTR    3756.151222
#
#     ========
#
#
#         Nombre: ['dfs', 'i']
#         miRNA predichos: 281442
#         Promedio por variante: mean    56288.40000
# std      8685.94559
# Name: count, dtype: float64
#         Region:
#             mean
#                       count
# Region
# 3'UTR   29197.2
# 5'UTR   27091.2,
#             std
#                           count
# Region
# 3'UTR   4970.428674
# 5'UTR   5758.070788
#
#     ========
#
#
#         Nombre: ['dfsp', 'i']
#         miRNA predichos: 196493
#         Promedio por variante: mean    49123.250000
# std      5522.901494
# Name: count, dtype: float64
#         Region:
#             mean
#                        count
# Region
# 3'UTR   31195.25
# 5'UTR   17928.00,
#             std
#                           count
# Region
# 3'UTR   8217.567092
# 5'UTR   3342.060043
#
#     ========

# %%
df_db2
# Out:
#                     Variant Region  count Table
# 0   (2010-12-05,2020-03-01]  3'UTR  15936   dft
# 1   (2010-12-05,2020-03-01]  5'UTR   7968   dft
# 2   (2020-03-01,2020-09-01]  3'UTR  21248   dft
# 3   (2020-03-01,2020-09-01]  5'UTR  13280   dft
# 4   (2020-09-01,2021-01-01]  3'UTR  31871   dft
# ..                      ...    ...    ...   ...
# 3                       Gs2  5'UTR  18592  dfsp
# 4                       Gs3  3'UTR  42479  dfsp
# 5                       Gs3  5'UTR  13280  dfsp
# 6                       Gs4  3'UTR  31856  dfsp
# 7                       Gs4  5'UTR  18592  dfsp
#
# [118 rows x 4 columns]

# %%
df_db2 = df_db2[df_db2['Table']!='dfs']
DF5 = df_db2[df_db2['Region']=="5'UTR"]
DF3 = df_db2[df_db2['Region']=="3'UTR"]

# %%
counts = DF5['count']

# Realizar la prueba de Shapiro-Wilk
stat, p_value = stats.shapiro(counts)
print(f'Estadístico: {stat}, p-valor: {p_value}')


model = ols('count ~ C(Table)', data=DF5).fit()

# Realizar el ANOVA
anova_table = sm.stats.anova_lm(model)
print(anova_table)
# Out:
# Estadístico: 0.9674748778343201, p-valor: 0.14897388219833374
#             df        sum_sq       mean_sq         F    PR(>F)
# C(Table)   3.0  1.031411e+08  3.438038e+07  1.426208  0.246144
# Residual  50.0  1.205308e+09  2.410615e+07       NaN       NaN

# %%
counts = DF3['count']

# Realizar la prueba de Shapiro-Wilk
stat, p_value = stats.shapiro(counts)
print(f'Estadístico: {stat}, p-valor: {p_value}')


groups = [group['count'].values for name, group in DF3.groupby('Table')]

# Realizar la prueba de Kruskal-Wallis
kruskal_result = stats.kruskal(*groups)
print(kruskal_result)
# Out:
# Estadístico: 0.9473559856414795, p-valor: 0.01911201700568199
# KruskalResult(statistic=22.31470358743671, pvalue=5.609904672701602e-05)

# %%
dunn_result = sp.posthoc_dunn(DF3, val_col='count', group_col='Table')
print(dunn_result)
# Out:
#           dfgt      dfsp       dft       dfv
# dfgt  1.000000  0.652427  0.850022  0.095124
# dfsp  0.652427  1.000000  0.680536  0.002324
# dft   0.850022  0.680536  1.000000  0.000134
# dfv   0.095124  0.002324  0.000134  1.000000

# %%
fig = plt.figure(figsize=(20, 4))
gs = gridspec.GridSpec(1, 4)

markers = {"5'UTR": 'o', "3'UTR": 'X'}

#===================================== First plot on the top =============================
ax1 = fig.add_subplot(gs[0, 0])
sns.kdeplot(data=dfv, x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                    markers=markers, style = 'Region', alpha = 0.3, ax=ax1, legend = False, palette = 'viridis')
sns.scatterplot(data=dfv[(dfv['DuplexEnergy']<=-10) & (dfv['Jaccard'] >=0.8)], x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                markers=markers, style = 'Region', alpha = 0.3, ax=ax1, legend = False, palette = 'viridis', s = 2)


plt.axvline(x=-10, color='r', linestyle='--')
plt.axhline(y=0.8, color='r', linestyle='--')


#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(ncol=2, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title("A", fontweight="bold", loc = 'left')
ax1.set_title('ACN', fontsize=10, pad=20)


ax4 = fig.add_subplot(gs[0, 1])
sns.kdeplot(data=dft, x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                    markers=markers, style = 'Region', alpha = 0.3, ax=ax4, legend = False, palette = 'viridis')
sns.scatterplot(data=dfv[(dfv['DuplexEnergy']<=-10) & (dfv['Jaccard'] >=0.8)], x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                markers=markers, style = 'Region', alpha = 0.3, ax=ax4, legend = False, palette = 'viridis', s = 2)


plt.axvline(x=-10, color='r', linestyle='--')
plt.axhline(y=0.8, color='r', linestyle='--')


#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(ncol=2, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title("B", fontweight="bold", loc = 'left')
ax4.set_title('AT', fontsize=10, pad=20)




ax2 = fig.add_subplot(gs[0, 2])
sns.kdeplot(data=dfsp, x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                    markers=markers, style = 'Region', alpha = 0.3, ax=ax2, legend = False, palette = 'Set2')
sns.scatterplot(data=dfsp[(dfsp['DuplexEnergy']<=-10) & (dfsp['Jaccard'] >=0.8)], x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                markers=markers, style = 'Region', alpha = 0.3, ax=ax2, legend = False, palette = 'Set2', s = 2)


plt.axvline(x=-10, color='r', linestyle='--')
plt.axhline(y=0.8, color='r', linestyle='--')


#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(ncol=2, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title("C", fontweight="bold", loc = 'left')
ax2.set_title('AGS', fontsize=10, pad=20)




ax3 = fig.add_subplot(gs[0, 3])
sns.kdeplot(data=dfgt, x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                    markers=markers, style = 'Region', alpha = 0.3, ax=ax3, legend = False, palette = 'Set2')
sns.scatterplot(data=dfgt[(dfgt['DuplexEnergy']<=-10) & (dfgt['Jaccard'] >=0.8)], x = 'DuplexEnergy', y = 'Jaccard', hue = 'Variant', 
                markers=markers, style = 'Region', alpha = 0.3, ax=ax3, legend = False, palette = 'Set2', s = 2)


plt.axvline(x=-10, color='r', linestyle='--')
plt.axhline(y=0.8, color='r', linestyle='--')


#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(ncol=2, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title("D", fontweight="bold", loc = 'left')
ax3.set_title('AGT', fontsize=10, pad=20)


#delete box
sns.despine(left=True, bottom=True)
plt.savefig('../../Plots/miRNAPredichos.pdf', bbox_inches='tight')
# Out:
# /home/ferambriz/.local/lib/python3.12/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'markers', 'style'
#   cset = contour_func(
# /home/ferambriz/.local/lib/python3.12/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'markers', 'style'
#   cset = contour_func(
# /home/ferambriz/.local/lib/python3.12/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'markers', 'style'
#   cset = contour_func(
# /home/ferambriz/.local/lib/python3.12/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'markers', 'style'
#   cset = contour_func(

# %% [markdown]
# # Estadisticas

# %%
def extract_variant(string):
    return string.split(':')[0].split('>')[1]
    
dfv['Variant'] = list(map(extract_variant, dfv['UTR_region']))
dfv

# %%
dfvi = pd.DataFrame(dfv[['Variant', 'Region']].value_counts()).reset_index()
dfvi.groupby(by='Region').agg(['mean', 'std'])

# %%
def extract_region(string):
    return string.split(':')[1]
dfv['RegionMap'] = list(map(extract_region, dfv['UTR_region']))

dfvr = pd.DataFrame(dfv[['RegionMap']].value_counts()).reset_index()
dfvr
# Out:
#        RegionMap       0
# 0    29696-29695  100928
# 1        256-255  100928
# 2        228-234   95616
# 3        224-223   74368
# 4    29871-29903   58102
# ..           ...     ...
# 259  29871-29902    2641
# 260  29871-29898    2641
# 261  29871-29891    2641
# 262  29871-29884    2641
# 263  29871-29875    2641
#
# [264 rows x 2 columns]

# %%
dft['Variant'] = list(map(extract_variant, dft['UTR_region']))
dft
# Out:
#                                   UTR_region             miRNA  \
# 0            >(2022-11-01,2023-01-01]:45-209      >hsa-miR-638
# 1            >(2021-05-01,2022-01-01]:26-173      >hsa-miR-638
# 2            >(2022-06-01,2022-11-01]:45-202      >hsa-miR-638
# 3            >(2023-07-01,2023-09-06]:45-202      >hsa-miR-638
# 4            >(2023-01-01,2023-07-01]:45-192      >hsa-miR-638
# ...                                      ...               ...
# 464681  >(2022-11-01,2023-01-01]:29890-29903   >hsa-miR-214-3p
# 464682  >(2022-11-01,2023-01-01]:29890-29903  >hsa-miR-4768-3p
# 464683  >(2023-01-01,2023-07-01]:29871-29903   >hsa-miR-214-3p
# 464684        >(2020-09-01,2021-01-01]:16-15  >hsa-miR-6891-3p
# 464685  >(2021-01-01,2021-05-01]:29728-29727  >hsa-miR-1249-3p
#
#                                                Prediction  \
# 0       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 1       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 2       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 3       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 4       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# ...                                                   ...
# 464681   .(.&.)   1,3   :  21,22  (4.00) i:13,j:22 <3.60>
# 464682   .(.&.)   1,3   :  19,20  (4.00) i:13,j:20 <3.60>
# 464683   .(.&.)   1,3   :  21,22  (4.00) i:32,j:22 <3.60>
# 464684     .(&.).   3,4   :   5,7   (4.00) i:4,j:6 <3.70>
# 464685    .(.&.)   1,3   :  21,22  (4.20) i:5,j:22 <3.80>
#
#                                               Interaction  \
# 0       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 1       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 2       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 3       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# 4       .((((((((((((.((((((.(((.&))).)).)))).))))))))...
# ...                                                   ...
# 464681                                             .(.&.)
# 464682                                             .(.&.)
# 464683                                             .(.&.)
# 464684                                             .(&.).
# 464685                                             .(.&.)
#
#        InteractionRegionUTR InteractionRegionmiRNA  DuplexEnergy  \
# 0                     45,69                   1,25         -34.5
# 1                     64,88                   1,25         -34.5
# 2                     45,69                   1,25         -34.5
# 3                     45,69                   1,25         -34.5
# 4                     45,69                   1,25         -34.5
# ...                     ...                    ...           ...
# 464681                  1,3                  21,22           4.0
# 464682                  1,3                  19,20           4.0
# 464683                  1,3                  21,22           4.0
# 464684                  3,4                    5,7           4.0
# 464685                  1,3                  21,22           4.2
#
#        InteractionResidues MinimumEnergy   Jaccard Region  \
# 0                 i:68,j:1      <-34.60>  0.840000  5'UTR
# 1                 i:87,j:1      <-34.60>  0.840000  5'UTR
# 2                 i:68,j:1      <-34.60>  0.840000  5'UTR
# 3                 i:68,j:1      <-34.60>  0.840000  5'UTR
# 4                 i:68,j:1      <-34.60>  0.840000  5'UTR
# ...                    ...           ...       ...    ...
# 464681           i:13,j:22        <3.60>  0.500000  3'UTR
# 464682           i:13,j:20        <3.60>  0.500000  3'UTR
# 464683           i:32,j:22        <3.60>  0.500000  3'UTR
# 464684             i:4,j:6        <3.70>  0.333333  5'UTR
# 464685            i:5,j:22        <3.80>  0.500000  3'UTR
#
#                         Variant
# 0       (2022-11-01,2023-01-01]
# 1       (2021-05-01,2022-01-01]
# 2       (2022-06-01,2022-11-01]
# 3       (2023-07-01,2023-09-06]
# 4       (2023-01-01,2023-07-01]
# ...                         ...
# 464681  (2022-11-01,2023-01-01]
# 464682  (2022-11-01,2023-01-01]
# 464683  (2023-01-01,2023-07-01]
# 464684  (2020-09-01,2021-01-01]
# 464685  (2021-01-01,2021-05-01]
#
# [464686 rows x 12 columns]

# %% [markdown]
# Nota. Un mismo miRNA puede interactuar en varios sitios

# %%
pd.DataFrame(dft[['Variant', 'Region']].value_counts()).agg(['mean', 'std'])
# Out:
#                  0
# mean  23234.300000
# std    8693.060161

# %%
dfti = pd.DataFrame(dft[['Variant', 'Region']].value_counts()).reset_index()
dfti.groupby(by='Region').agg(['mean', 'std'])
# Out:
# /tmp/ipykernel_11146/2832634115.py:2: FutureWarning: ['Variant'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   dfti.groupby(by='Region').agg(['mean', 'std'])
#               0
#            mean          std
# Region
# 3'UTR   28939.0  7660.626113
# 5'UTR   17529.6  5341.429588

# %%
dft['RegionMap'] = list(map(extract_region, dft['UTR_region']))

dfvt = pd.DataFrame(dft[['RegionMap']].value_counts()).reset_index()
dfvt
# Out:
#       RegionMap      0
# 0   29696-29695  26560
# 1       256-255  26560
# 2   29824-29823  21248
# 3   29776-29775  18592
# 4   29701-29705  15930
# ..          ...    ...
# 78  29745-29750   2656
# 79  29711-29717   2655
# 80  29896-29895   2641
# 81  29888-29887   2641
# 82  29890-29903   2641
#
# [83 rows x 2 columns]

# %% [markdown]
# # Filtro

# %%
df_vf = dfv[(dfv['DuplexEnergy']<=-10) & (dfv['Jaccard'] >=0.8)]
df_tf = dft[(dft['DuplexEnergy']<=-10) & (dft['Jaccard'] >=0.8)]
dfgtf = dfgt[(dfgt['DuplexEnergy']<=-10) & (dfgt['Jaccard'] >=0.8)]
dfsf = dfs[(dfs['DuplexEnergy']<=-10) & (dfs['Jaccard'] >=0.8)]
dfspf = dfsp[(dfsp['DuplexEnergy']<=-10) & (dfsp['Jaccard'] >=0.8)]

# %%
df_list = [df_tf, df_vf, dfgtf, dfsf, dfspf]
df_db2 = pd.DataFrame()

for i in df_list:
    ii = i[i['Variant']!='Global']
    df_name = [name for name in globals() if globals()[name] is i]

    df_i = pd.DataFrame(ii['Variant'].value_counts())
    df_i['Table'] = [df_name[1]] * len(df_i)
    df_i['Filter'] = 'Jaccard_Duplex'

    df_i2 = pd.DataFrame(ii[['Variant', 'Region']].groupby('Variant').value_counts().reset_index())
    df_i2['Table'] = df_name[1]


    print(f'''
        Nombre: {df_name}
        miRNA predichos: {len(ii)}
        Promedio por variante: {ii['Variant'].value_counts().agg(['mean', 'std'], numeric_only=True)}
        Region:
            mean
            {ii[['Variant', 'Region']].groupby('Variant').value_counts().reset_index().groupby('Region').mean(numeric_only=True)},
            std
            {ii[['Variant', 'Region']].groupby('Variant').value_counts().reset_index().groupby('Region').std(numeric_only=True)}

    ========
    ''')
    df_db = pd.concat([df_db, df_i])
    df_db2 = pd.concat([df_db2, df_i2])
# Out:
#         Nombre: ['i', 'df_tf']
#         miRNA predichos: 11469
#         Promedio por variante: mean    1146.900000
# std      156.868983
# Name: count, dtype: float64
#         Region:
#             mean
#                     count
# Region
# 3'UTR   374.8
# 5'UTR   772.1,
#             std
#                          count
# Region
# 3'UTR    97.376474
# 5'UTR   236.161644
#
#     ========
#
#
#         Nombre: ['i', 'df_vf']
#         miRNA predichos: 45014
#         Promedio por variante: mean    1184.578947
# std      237.030917
# Name: count, dtype: float64
#         Region:
#             mean
#                          count
# Region
# 3'UTR   485.789474
# 5'UTR   698.789474,
#             std
#                          count
# Region
# 3'UTR   137.368346
# 5'UTR   178.528392
#
#     ========
#
#
#         Nombre: ['i', 'dfgtf']
#         miRNA predichos: 2988
#         Promedio por variante: mean    1494.000000
# std      288.499567
# Name: count, dtype: float64
#         Region:
#             mean
#                     count
# Region
# 3'UTR   557.5
# 5'UTR   936.5,
#             std
#                          count
# Region
# 3'UTR    26.162951
# 5'UTR   314.662518
#
#     ========
#
#
#         Nombre: ['i', 'dfsf']
#         miRNA predichos: 7474
#         Promedio por variante: mean    1494.800000
# std       88.860565
# Name: count, dtype: float64
#         Region:
#             mean
#                      count
# Region
# 3'UTR    466.6
# 5'UTR   1028.2,
#             std
#                          count
# Region
# 3'UTR   140.038566
# 5'UTR   122.567124
#
#     ========
#
#
#         Nombre: ['i', 'dfspf']
#         miRNA predichos: 4608
#         Promedio por variante: mean    1152.00000
# std      187.20755
# Name: count, dtype: float64
#         Region:
#             mean
#                     count
# Region
# 3'UTR   351.5
# 5'UTR   800.5,
#             std
#                          count
# Region
# 3'UTR   116.563288
# 5'UTR   149.885512
#
#     ========

# %%
df_db.to_csv('../../Data/Filters.tsv', sep = '\t')
df_db
# Out:
#                          count  Table          Filter
# Variant
# (2021-01-01,2021-05-01]  63742    dft          Global
# (2020-09-01,2021-01-01]  58431    dft          Global
# (2021-05-01,2022-01-01]  58416    dft          Global
# (2023-07-01,2023-09-06]  50448    dft          Global
# (2023-01-01,2023-07-01]  47792    dft          Global
# ...                        ...    ...             ...
# G3                        1361   dfsf  Jaccard_Duplex
# Gs1                       1361  dfspf  Jaccard_Duplex
# Gs3                       1255  dfspf  Jaccard_Duplex
# Gs2                       1029  dfspf  Jaccard_Duplex
# Gs4                        963  dfspf  Jaccard_Duplex
#
# [236 rows x 3 columns]

# %%
df_db2
# Out:
#                     Variant Region  count  Table
# 0   (2010-12-05,2020-03-01]  3'UTR    466  df_tf
# 1   (2010-12-05,2020-03-01]  5'UTR    461  df_tf
# 2   (2020-03-01,2020-09-01]  5'UTR    573  df_tf
# 3   (2020-03-01,2020-09-01]  3'UTR    527  df_tf
# 4   (2020-09-01,2021-01-01]  5'UTR   1157  df_tf
# ..                      ...    ...    ...    ...
# 3                       Gs2  3'UTR    191  dfspf
# 4                       Gs3  5'UTR    788  dfspf
# 5                       Gs3  3'UTR    467  dfspf
# 6                       Gs4  5'UTR    607  dfspf
# 7                       Gs4  3'UTR    356  dfspf
#
# [118 rows x 4 columns]

# %%
lst = []
for i in df_tf['miRNA']:
    lst.append(i.split('>')[1])
df_tf['miRNA_lite'] = lst

lst = []
for i in df_vf['miRNA']:
    lst.append(i.split('>')[1])
df_vf['miRNA_lite'] = lst

lst = []
for i in dfgtf['miRNA']:
    lst.append(i.split('>')[1])
dfgtf['miRNA_lite'] = lst

lst = []
for i in dfsf['miRNA']:
    lst.append(i.split('>')[1])
dfsf['miRNA_lite'] = lst

lst = []
for i in dfspf['miRNA']:
    lst.append(i.split('>')[1])
dfspf['miRNA_lite'] = lst
# Out:
# /tmp/ipykernel_4421/1249333052.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tf['miRNA_lite'] = lst
# /tmp/ipykernel_4421/1249333052.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vf['miRNA_lite'] = lst
# /tmp/ipykernel_4421/1249333052.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfgtf['miRNA_lite'] = lst
# /tmp/ipykernel_4421/1249333052.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsf['miRNA_lite'] = lst
# /tmp/ipykernel_4421/1249333052.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfspf['miRNA_lite'] = lst

# %%
df_vf.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conservedSinEstructuraSecundaria_Variants_Filtrado.tsv', sep = '\t', index = False)
df_tf.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Time_Filtrado.tsv', sep = '\t', index = False)
dfgtf.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_ConstantClusters_Filtrado.tsv', sep = '\t', index = False)
dfsf.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Spectral_Filtrado.tsv', sep = '\t', index = False)
dfspf.to_csv('../../Data/Estratos/miRNA_predict/miRNA_conserved_Spectrum_Filtrado.tsv', sep = '\t', index = False)

# %% [markdown]
# # Inspeccion

# %%
dfvif = pd.DataFrame(df_vf[['Variant', 'Region']].value_counts()).reset_index()
dfvif.groupby(by='Region').agg(['mean', 'std'])
# Out:
# /tmp/ipykernel_4421/1984861854.py:2: FutureWarning: ['Variant'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   dfvif.groupby(by='Region').agg(['mean', 'std'])
#                  0
#               mean         std
# Region
# 3'UTR   485.789474  137.368346
# 5'UTR   698.789474  178.528392

# %%
len(df_tf)
# Out:
# 11725

# %%
dftif = pd.DataFrame(df_tf[['Variant', 'Region']].value_counts()).reset_index()
dftif.groupby(by='Region').agg(['mean', 'std'])
# Out:
# /tmp/ipykernel_12189/1646039635.py:2: FutureWarning: ['Variant'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   dftif.groupby(by='Region').agg(['mean', 'std'])
#                  0
#               mean         std
# Region
# 3'UTR   379.818182   80.537964
# 5'UTR   686.090909  151.389864

# %%
bxv = pd.DataFrame(df_vf[['Variant', 'Region']].value_counts()).reset_index()
bxt = pd.DataFrame(df_tf[['Variant', 'Region']].value_counts()).reset_index()
bxgt = pd.DataFrame(dfgtf[['Variant', 'Region']].value_counts()).reset_index()
bxs = pd.DataFrame(dfsf[['Variant', 'Region']].value_counts()).reset_index()
bxsp = pd.DataFrame(dfspf[['Variant', 'Region']].value_counts()).reset_index()

# %%
def estadistico(df):
    df5 = df[df['Region'] == "5'UTR"]
    df3 = df[df['Region'] == "3'UTR"]


    shapiro_test5 = stats.shapiro(df5[0])    
    shapiro_test3 = stats.shapiro(df3[0])
    print(f'shapiro wilk{shapiro_test5.pvalue, shapiro_test3.pvalue}')
    if shapiro_test5.pvalue > 0.05 and shapiro_test3.pvalue > 0.05:
        print('t-student')
        test = stats.ttest_ind(df5[0], df3[0])
    else:
        print('mannwhitneu')
        test = stats.mannwhitneyu(df5[0], df3[0])
    return test

# %%
estadistico(bxt)
# Out:
# shapiro wilk(0.4455223083496094, 0.9768904447555542)
# t-student
# TtestResult(statistic=5.923688280836523, pvalue=8.56746278964184e-06, df=20.0)

# %%
estadistico(bxv)
# Out:
# shapiro wilk(0.3442733585834503, 0.019390715286135674)
# mannwhitneu
# MannwhitneyuResult(statistic=1429.0, pvalue=2.4547958115467475e-11)

# %%
fig = plt.figure(figsize=(10, 3))
gs = gridspec.GridSpec(1, 3)

#===================================== First plot on the top =============================
#ax1 = fig.add_subplot(gs[0, 0])
#sns.histplot(data=df_vf, x="Variant", kde=True, hue="Region", alpha =0.2, ax=ax1)
#ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90, fontsize = 8)
#===================================== Second plot on the top =============================
#ax2 = fig.add_subplot(gs[0, 1])
#sns.histplot(data=df_tf.sort_values(by=['Variant']), x="Variant", kde=True, hue="Region", alpha =0.2, ax=ax2)
#ax2.set_xticklabels(ax2.get_xticklabels(), rotation=70, fontsize = 7)
#===================================== Third plot on the top =============================
ax3 = fig.add_subplot(gs[0, 0])
sns.violinplot(data=bxv, x="Region", y=0, hue="Region", fill=False, ax = ax3, split = True)
sns.stripplot(data=bxv, x="Region", y=0, hue="Region", dodge=True, jitter=True, ax=ax3)

# Barra de significancia
y_max = max(bxv[0]) + 100
y_min = min(bxv[0]) + 100
y = y_max + (y_max - y_min) * 0.1  
plt.plot([0, 1], [y, y], color='gray') 
plt.text(0.5, y, "***", ha='center') 

plt.ylabel('Conteo')

plt.title("A", fontweight="bold", loc = 'left')
ax3.set_title('miRNA por variante', fontsize=10, pad=20)
#===================================== Four plot on the top =============================
#ax4 = fig.add_subplot(gs[0, 1])
#sns.violinplot(data=bxt, x="Region", y=0, hue="Region", fill=False, ax = ax4, split = True)
#sns.stripplot(data=bxt, x="Region", y=0, hue="Region", dodge=True, jitter=True, ax=ax4)

# Barra de significancia
#y_max = max(bxt[0]) + 160
#y_min = min(bxt[0]) + 160
#y = y_max + (y_max - y_min) * 0.1  
#plt.plot([0, 1], [y, y], color='gray') 
#plt.text(0.5, y, "***", ha='center') 

#plt.ylabel('Conteo')

#plt.title("B", fontweight="bold", loc = 'left')
#ax4.set_title('miRNA por cluster', fontsize=10, pad=20)

#===================================== Four plot on the top =============================

ax5 = fig.add_subplot(gs[0, 1])
sns.violinplot(data=bxsp, x="Region", y=0, hue="Region", fill=False, ax = ax5, split = True)
sns.stripplot(data=bxsp, x="Region", y=0, hue="Region", dodge=True, jitter=True, ax=ax5)

# Barra de significancia
y_max = max(bxsp[0]) + 160
y_min = min(bxsp[0]) + 160
y = y_max + (y_max - y_min) * 0.1  
plt.plot([0, 1], [y, y], color='gray') 
plt.text(0.5, y, "***", ha='center') 

plt.ylabel('Conteo')

plt.title("B", fontweight="bold", loc = 'left')
ax5.set_title('miRNA por GC', fontsize=10, pad=20)

#===================================== Four plot on the top =============================
ax6 = fig.add_subplot(gs[0, 2])
sns.violinplot(data=bxgt, x="Region", y=0, hue="Region", fill=False, ax = ax6, split = True)
sns.stripplot(data=bxgt, x="Region", y=0, hue="Region", dodge=True, jitter=True, ax=ax6)

# Barra de significancia
#y_max = max(bxgt[0]) + 160
#y_min = min(bxgt[0]) + 160
#y = y_max + (y_max - y_min) * 0.1  
#plt.plot([0, 1], [y, y], color='gray') 
#plt.text(0.5, y, "***", ha='center') 

plt.ylabel('Conteo')

plt.title("C", fontweight="bold", loc = 'left')
ax6.set_title('miRNA de por GC en t', fontsize=10, pad=20)


#delete box
sns.despine(left=True, bottom=True)
plt.subplots_adjust(hspace=1, wspace=0.5)
plt.savefig('../../Plots/FilterSummary.pdf', bbox_inches='tight')
