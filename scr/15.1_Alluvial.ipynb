# %%
library(ggplot2)
library(ggalluvial)
library(tidyverse)

# %%
df = read_tsv('/home/ferambriz/test.tsv')
df
# Out:
# Rows: 150 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): Via, tiempo
# dbl (2): conteo, RF
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     Via                                                 tiempo
# 1   Regulación positiva de proliferación celular        (2021-05-01,2022-01-01]
# 2   Regulación positiva de proliferación celular        (2022-06-01,2022-11-01]
# 3   Regulación positiva de proliferación celular        (2021-01-01,2021-05-01]
# 4   Regulación positiva de proliferación celular        (2023-01-01,2023-07-01]
# 5   Regulación positiva de proliferación celular        (2020-09-01,2021-01-01]
# 6   Regulación positiva de proliferación celular        (2023-07-01,2023-09-06]
# 7   Regulación positiva de proliferación celular        (2022-01-01,2022-06-01]
# ...

# %%
options(repr.plot.width = 15, repr.plot.height = 10)

pdf('../../Plots/AlluvialPlot.pdf', width = 17, height = 10)

ggplot(df, aes(x = tiempo, stratum = Via, alluvium = Via, y = RF, fill = Via)) +
  geom_flow(stat = "alluvium", lode.guidance = "frontback") +
  geom_stratum(color = NA) +
  scale_x_discrete(limits = c("(2010-12-05,2020-03-01]","(2020-03-01,2020-09-01]", "(2020-09-01,2021-01-01]", "(2021-01-01,2021-05-01]",
  "(2021-05-01,2022-01-01]","(2022-01-01,2022-06-01]","(2022-06-01,2022-11-01]", "(2022-11-01,2023-01-01]","(2023-01-01,2023-07-01]",
  "(2023-07-01,2023-09-06]"), expand = c(0.01, 0.05)) +
  theme_minimal() +
  theme(legend.position = "bottom",
        axis.text.x = element_text(angle = 90, hjust = 1)) +
  labs(title = "Vias metabolicas reguladas a través de t", x = "Tiempo", y = "RF")
dev.off()
# Out:
# png
#   2
